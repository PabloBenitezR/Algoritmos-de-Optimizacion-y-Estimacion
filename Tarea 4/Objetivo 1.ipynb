# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# parámetros
R_real = 100       # resistencia en ohmios
C = 1e-3           # capacitancia en faradios
RC = R_real * C    # constante de tiempo
T = 10             # tiempo (s) total de simulación
h = RC / 10        # paso de integración estable
N = int(T / h)     # númerp de iteraciones
t = np.linspace(0, T, N)

# función senoidal de 1 Hz
Vin = np.sin(5 * np.pi * t)

# %%
# método de Euler explícito
Vc_real = np.zeros(N)
for k in range(N - 1):
    Vc_real[k+1] = Vc_real[k] + h * (Vin[k] - Vc_real[k]) / RC

# %%
# método de cálculo de Vc dado un R
def simular(R, Vin, t, C, h):
    Vc = np.zeros(len(t))
    RC_local = R * C
    for k in range(len(t) - 1):
        Vc[k+1] = Vc[k] + h * (Vin[k] - Vc[k]) / RC_local
    return Vc

# %%
# error cuadrático medio
def error(Vc_sim, Vc_real):
    return (1/2) * np.sum((Vc_real - Vc_sim)**2)

# %%
# derivar el error cuadrático respecto a R
def gradiente(R, Vin, Vc_real, t, C, h):
    Vc = np.zeros(len(t))
    dVc_dR = np.zeros(len(t))

    RC_local = R * C
    
    for k in range(len(t) - 1):
        dVc = h * (Vin[k] - Vc[k]) / RC_local
        ddVc_dR = h * (- (Vin[k] - Vc[k]) / (RC_local**2) * C - dVc_dR[k] / RC_local)
        Vc[k+1] = Vc[k] + dVc
        dVc_dR[k+1] = dVc_dR[k] + ddVc_dR
    grad = -np.sum((Vc_real - Vc) * dVc_dR)
    return grad

# %%
# gradiente descendente
R_hat = 70.0   # estimación inicial de R
alpha = 1e-2   # tasa de aprendizaje
tol = 1e-3     # tolerancia
num_iter = 1000 # número de iteraciones

for i in range(num_iter):
    Vc_sim = simular(R_hat, Vin, t, C, h)
    J = error(Vc_sim, Vc_real)
    grad = gradiente(R_hat, Vin, Vc_real, t, C, h)
    
    R_old = R_hat
    R_hat = R_hat - alpha * grad
    
    print(f"Iteración {i+1}: R_hat = {R_hat:.4f}, Error = {J:.4f}")
    
    if abs(R_hat - R_old) < tol:
        print(f"\nConvergencia alcanzada en la iteración {i+1}")
        break

print(f"\nR estimada = {R_hat:.4f} Ohms (R real = {R_real} Ohms)")
# Out:
# Iteración 1: R_hat = 70.0069, Error = 8.3965
# Iteración 2: R_hat = 70.0138, Error = 8.3917
# Iteración 3: R_hat = 70.0207, Error = 8.3869
# Iteración 4: R_hat = 70.0276, Error = 8.3821
# Iteración 5: R_hat = 70.0345, Error = 8.3774
# Iteración 6: R_hat = 70.0414, Error = 8.3726
# Iteración 7: R_hat = 70.0483, Error = 8.3678
# Iteración 8: R_hat = 70.0552, Error = 8.3631
# Iteración 9: R_hat = 70.0621, Error = 8.3583
# Iteración 10: R_hat = 70.0690, Error = 8.3536
# Iteración 11: R_hat = 70.0759, Error = 8.3488
# Iteración 12: R_hat = 70.0828, Error = 8.3441
# Iteración 13: R_hat = 70.0897, Error = 8.3394
# Iteración 14: R_hat = 70.0965, Error = 8.3346
# Iteración 15: R_hat = 70.1034, Error = 8.3299
# Iteración 16: R_hat = 70.1103, Error = 8.3252
# Iteración 17: R_hat = 70.1172, Error = 8.3204
# Iteración 18: R_hat = 70.1240, Error = 8.3157
# Iteración 19: R_hat = 70.1309, Error = 8.3110
# Iteración 20: R_hat = 70.1378, Error = 8.3063
# Iteración 21: R_hat = 70.1446, Error = 8.3016
# Iteración 22: R_hat = 70.1515, Error = 8.2969
# Iteración 23: R_hat = 70.1583, Error = 8.2922
# Iteración 24: R_hat = 70.1652, Error = 8.2875
# Iteración 25: R_hat = 70.1720, Error = 8.2828
# Iteración 26: R_hat = 70.1789, Error = 8.2781
# Iteración 27: R_hat = 70.1857, Error = 8.2734
# Iteración 28: R_hat = 70.1926, Error = 8.2687
# Iteración 29: R_hat = 70.1994, Error = 8.2640
# Iteración 30: R_hat = 70.2063, Error = 8.2594
# Iteración 31: R_hat = 70.2131, Error = 8.2547
# Iteración 32: R_hat = 70.2199, Error = 8.2500
# Iteración 33: R_hat = 70.2267, Error = 8.2453
# Iteración 34: R_hat = 70.2336, Error = 8.2407
# Iteración 35: R_hat = 70.2404, Error = 8.2360
# Iteración 36: R_hat = 70.2472, Error = 8.2314
# Iteración 37: R_hat = 70.2540, Error = 8.2267
# Iteración 38: R_hat = 70.2609, Error = 8.2221
# Iteración 39: R_hat = 70.2677, Error = 8.2174
# Iteración 40: R_hat = 70.2745, Error = 8.2128
# Iteración 41: R_hat = 70.2813, Error = 8.2081
# Iteración 42: R_hat = 70.2881, Error = 8.2035
# Iteración 43: R_hat = 70.2949, Error = 8.1989
# Iteración 44: R_hat = 70.3017, Error = 8.1942
# Iteración 45: R_hat = 70.3085, Error = 8.1896
# Iteración 46: R_hat = 70.3153, Error = 8.1850
# Iteración 47: R_hat = 70.3221, Error = 8.1804
# Iteración 48: R_hat = 70.3289, Error = 8.1758
# Iteración 49: R_hat = 70.3357, Error = 8.1712
# Iteración 50: R_hat = 70.3425, Error = 8.1666
# Iteración 51: R_hat = 70.3492, Error = 8.1619
# Iteración 52: R_hat = 70.3560, Error = 8.1573
# Iteración 53: R_hat = 70.3628, Error = 8.1528
# Iteración 54: R_hat = 70.3696, Error = 8.1482
# Iteración 55: R_hat = 70.3763, Error = 8.1436
# Iteración 56: R_hat = 70.3831, Error = 8.1390
# Iteración 57: R_hat = 70.3899, Error = 8.1344
# Iteración 58: R_hat = 70.3966, Error = 8.1298
# Iteración 59: R_hat = 70.4034, Error = 8.1252
# Iteración 60: R_hat = 70.4102, Error = 8.1207
# Iteración 61: R_hat = 70.4169, Error = 8.1161
# Iteración 62: R_hat = 70.4237, Error = 8.1115
# Iteración 63: R_hat = 70.4304, Error = 8.1070
# Iteración 64: R_hat = 70.4372, Error = 8.1024
# Iteración 65: R_hat = 70.4439, Error = 8.0979
# Iteración 66: R_hat = 70.4507, Error = 8.0933
# Iteración 67: R_hat = 70.4574, Error = 8.0888
# Iteración 68: R_hat = 70.4642, Error = 8.0842
# Iteración 69: R_hat = 70.4709, Error = 8.0797
# Iteración 70: R_hat = 70.4776, Error = 8.0751
# Iteración 71: R_hat = 70.4844, Error = 8.0706
# Iteración 72: R_hat = 70.4911, Error = 8.0661
# Iteración 73: R_hat = 70.4978, Error = 8.0616
# Iteración 74: R_hat = 70.5045, Error = 8.0570
# Iteración 75: R_hat = 70.5113, Error = 8.0525
# Iteración 76: R_hat = 70.5180, Error = 8.0480
# Iteración 77: R_hat = 70.5247, Error = 8.0435
# Iteración 78: R_hat = 70.5314, Error = 8.0390
# Iteración 79: R_hat = 70.5381, Error = 8.0345
# Iteración 80: R_hat = 70.5448, Error = 8.0300
# Iteración 81: R_hat = 70.5515, Error = 8.0255
# Iteración 82: R_hat = 70.5582, Error = 8.0210
# Iteración 83: R_hat = 70.5649, Error = 8.0165
# Iteración 84: R_hat = 70.5716, Error = 8.0120
# Iteración 85: R_hat = 70.5783, Error = 8.0075
# Iteración 86: R_hat = 70.5850, Error = 8.0030
# Iteración 87: R_hat = 70.5917, Error = 7.9985
# Iteración 88: R_hat = 70.5984, Error = 7.9940
# Iteración 89: R_hat = 70.6051, Error = 7.9896
# Iteración 90: R_hat = 70.6118, Error = 7.9851
# Iteración 91: R_hat = 70.6185, Error = 7.9806
# Iteración 92: R_hat = 70.6251, Error = 7.9762
# Iteración 93: R_hat = 70.6318, Error = 7.9717
# Iteración 94: R_hat = 70.6385, Error = 7.9673
# Iteración 95: R_hat = 70.6452, Error = 7.9628
# Iteración 96: R_hat = 70.6518, Error = 7.9584
# Iteración 97: R_hat = 70.6585, Error = 7.9539
# Iteración 98: R_hat = 70.6652, Error = 7.9495
# Iteración 99: R_hat = 70.6718, Error = 7.9450
# Iteración 100: R_hat = 70.6785, Error = 7.9406
# Iteración 101: R_hat = 70.6851, Error = 7.9362
# Iteración 102: R_hat = 70.6918, Error = 7.9317
# Iteración 103: R_hat = 70.6984, Error = 7.9273
# Iteración 104: R_hat = 70.7051, Error = 7.9229
# Iteración 105: R_hat = 70.7117, Error = 7.9185
# Iteración 106: R_hat = 70.7184, Error = 7.9140
# Iteración 107: R_hat = 70.7250, Error = 7.9096
# Iteración 108: R_hat = 70.7317, Error = 7.9052
# Iteración 109: R_hat = 70.7383, Error = 7.9008
# Iteración 110: R_hat = 70.7449, Error = 7.8964
# Iteración 111: R_hat = 70.7516, Error = 7.8920
# Iteración 112: R_hat = 70.7582, Error = 7.8876
# Iteración 113: R_hat = 70.7648, Error = 7.8832
# Iteración 114: R_hat = 70.7714, Error = 7.8788
# Iteración 115: R_hat = 70.7781, Error = 7.8744
# Iteración 116: R_hat = 70.7847, Error = 7.8701
# Iteración 117: R_hat = 70.7913, Error = 7.8657
# Iteración 118: R_hat = 70.7979, Error = 7.8613
# Iteración 119: R_hat = 70.8045, Error = 7.8569
# Iteración 120: R_hat = 70.8111, Error = 7.8526
# Iteración 121: R_hat = 70.8177, Error = 7.8482
# Iteración 122: R_hat = 70.8243, Error = 7.8438
# Iteración 123: R_hat = 70.8309, Error = 7.8395
# Iteración 124: R_hat = 70.8375, Error = 7.8351
# Iteración 125: R_hat = 70.8441, Error = 7.8307
# Iteración 126: R_hat = 70.8507, Error = 7.8264
# Iteración 127: R_hat = 70.8573, Error = 7.8220
# Iteración 128: R_hat = 70.8639, Error = 7.8177
# Iteración 129: R_hat = 70.8705, Error = 7.8134
# Iteración 130: R_hat = 70.8771, Error = 7.8090
# Iteración 131: R_hat = 70.8837, Error = 7.8047
# Iteración 132: R_hat = 70.8903, Error = 7.8004
# Iteración 133: R_hat = 70.8968, Error = 7.7960
# Iteración 134: R_hat = 70.9034, Error = 7.7917
# Iteración 135: R_hat = 70.9100, Error = 7.7874
# Iteración 136: R_hat = 70.9165, Error = 7.7831
# Iteración 137: R_hat = 70.9231, Error = 7.7787
# Iteración 138: R_hat = 70.9297, Error = 7.7744
# Iteración 139: R_hat = 70.9362, Error = 7.7701
# Iteración 140: R_hat = 70.9428, Error = 7.7658
# Iteración 141: R_hat = 70.9494, Error = 7.7615
# Iteración 142: R_hat = 70.9559, Error = 7.7572
# Iteración 143: R_hat = 70.9625, Error = 7.7529
# Iteración 144: R_hat = 70.9690, Error = 7.7486
# Iteración 145: R_hat = 70.9756, Error = 7.7443
# Iteración 146: R_hat = 70.9821, Error = 7.7400
# Iteración 147: R_hat = 70.9887, Error = 7.7358
# Iteración 148: R_hat = 70.9952, Error = 7.7315
# Iteración 149: R_hat = 71.0017, Error = 7.7272
# Iteración 150: R_hat = 71.0083, Error = 7.7229
# Iteración 151: R_hat = 71.0148, Error = 7.7187
# Iteración 152: R_hat = 71.0213, Error = 7.7144
# Iteración 153: R_hat = 71.0279, Error = 7.7101
# Iteración 154: R_hat = 71.0344, Error = 7.7059
# Iteración 155: R_hat = 71.0409, Error = 7.7016
# Iteración 156: R_hat = 71.0474, Error = 7.6974
# Iteración 157: R_hat = 71.0540, Error = 7.6931
# Iteración 158: R_hat = 71.0605, Error = 7.6889
# Iteración 159: R_hat = 71.0670, Error = 7.6846
# Iteración 160: R_hat = 71.0735, Error = 7.6804
# Iteración 161: R_hat = 71.0800, Error = 7.6761
# Iteración 162: R_hat = 71.0865, Error = 7.6719
# Iteración 163: R_hat = 71.0930, Error = 7.6677
# Iteración 164: R_hat = 71.0995, Error = 7.6634
# Iteración 165: R_hat = 71.1060, Error = 7.6592
# Iteración 166: R_hat = 71.1125, Error = 7.6550
# Iteración 167: R_hat = 71.1190, Error = 7.6508
# Iteración 168: R_hat = 71.1255, Error = 7.6465
# Iteración 169: R_hat = 71.1320, Error = 7.6423
# Iteración 170: R_hat = 71.1385, Error = 7.6381
# Iteración 171: R_hat = 71.1450, Error = 7.6339
# Iteración 172: R_hat = 71.1515, Error = 7.6297
# Iteración 173: R_hat = 71.1579, Error = 7.6255
# Iteración 174: R_hat = 71.1644, Error = 7.6213
# Iteración 175: R_hat = 71.1709, Error = 7.6171
# Iteración 176: R_hat = 71.1774, Error = 7.6129
# Iteración 177: R_hat = 71.1838, Error = 7.6087
# Iteración 178: R_hat = 71.1903, Error = 7.6045
# Iteración 179: R_hat = 71.1968, Error = 7.6003
# Iteración 180: R_hat = 71.2032, Error = 7.5962
# Iteración 181: R_hat = 71.2097, Error = 7.5920
# Iteración 182: R_hat = 71.2162, Error = 7.5878
# Iteración 183: R_hat = 71.2226, Error = 7.5836
# Iteración 184: R_hat = 71.2291, Error = 7.5795
# Iteración 185: R_hat = 71.2355, Error = 7.5753
# Iteración 186: R_hat = 71.2420, Error = 7.5711
# Iteración 187: R_hat = 71.2484, Error = 7.5670
# Iteración 188: R_hat = 71.2549, Error = 7.5628
# Iteración 189: R_hat = 71.2613, Error = 7.5587
# Iteración 190: R_hat = 71.2677, Error = 7.5545
# Iteración 191: R_hat = 71.2742, Error = 7.5504
# Iteración 192: R_hat = 71.2806, Error = 7.5462
# Iteración 193: R_hat = 71.2870, Error = 7.5421
# Iteración 194: R_hat = 71.2935, Error = 7.5380
# Iteración 195: R_hat = 71.2999, Error = 7.5338
# Iteración 196: R_hat = 71.3063, Error = 7.5297
# Iteración 197: R_hat = 71.3128, Error = 7.5256
# Iteración 198: R_hat = 71.3192, Error = 7.5214
# Iteración 199: R_hat = 71.3256, Error = 7.5173
# Iteración 200: R_hat = 71.3320, Error = 7.5132
# Iteración 201: R_hat = 71.3384, Error = 7.5091
# Iteración 202: R_hat = 71.3448, Error = 7.5050
# Iteración 203: R_hat = 71.3513, Error = 7.5008
# Iteración 204: R_hat = 71.3577, Error = 7.4967
# Iteración 205: R_hat = 71.3641, Error = 7.4926
# Iteración 206: R_hat = 71.3705, Error = 7.4885
# Iteración 207: R_hat = 71.3769, Error = 7.4844
# Iteración 208: R_hat = 71.3833, Error = 7.4803
# Iteración 209: R_hat = 71.3897, Error = 7.4762
# Iteración 210: R_hat = 71.3961, Error = 7.4722
# Iteración 211: R_hat = 71.4024, Error = 7.4681
# Iteración 212: R_hat = 71.4088, Error = 7.4640
# Iteración 213: R_hat = 71.4152, Error = 7.4599
# Iteración 214: R_hat = 71.4216, Error = 7.4558
# Iteración 215: R_hat = 71.4280, Error = 7.4518
# Iteración 216: R_hat = 71.4344, Error = 7.4477
# Iteración 217: R_hat = 71.4407, Error = 7.4436
# Iteración 218: R_hat = 71.4471, Error = 7.4395
# Iteración 219: R_hat = 71.4535, Error = 7.4355
# Iteración 220: R_hat = 71.4599, Error = 7.4314
# Iteración 221: R_hat = 71.4662, Error = 7.4274
# Iteración 222: R_hat = 71.4726, Error = 7.4233
# Iteración 223: R_hat = 71.4790, Error = 7.4193
# Iteración 224: R_hat = 71.4853, Error = 7.4152
# Iteración 225: R_hat = 71.4917, Error = 7.4112
# Iteración 226: R_hat = 71.4980, Error = 7.4071
# Iteración 227: R_hat = 71.5044, Error = 7.4031
# Iteración 228: R_hat = 71.5107, Error = 7.3991
# Iteración 229: R_hat = 71.5171, Error = 7.3950
# Iteración 230: R_hat = 71.5234, Error = 7.3910
# Iteración 231: R_hat = 71.5298, Error = 7.3870
# Iteración 232: R_hat = 71.5361, Error = 7.3829
# Iteración 233: R_hat = 71.5425, Error = 7.3789
# Iteración 234: R_hat = 71.5488, Error = 7.3749
# Iteración 235: R_hat = 71.5551, Error = 7.3709
# Iteración 236: R_hat = 71.5615, Error = 7.3669
# Iteración 237: R_hat = 71.5678, Error = 7.3629
# Iteración 238: R_hat = 71.5741, Error = 7.3588
# Iteración 239: R_hat = 71.5805, Error = 7.3548
# Iteración 240: R_hat = 71.5868, Error = 7.3508
# Iteración 241: R_hat = 71.5931, Error = 7.3468
# Iteración 242: R_hat = 71.5994, Error = 7.3428
# Iteración 243: R_hat = 71.6057, Error = 7.3389
# Iteración 244: R_hat = 71.6120, Error = 7.3349
# Iteración 245: R_hat = 71.6184, Error = 7.3309
# Iteración 246: R_hat = 71.6247, Error = 7.3269
# Iteración 247: R_hat = 71.6310, Error = 7.3229
# Iteración 248: R_hat = 71.6373, Error = 7.3189
# Iteración 249: R_hat = 71.6436, Error = 7.3150
# Iteración 250: R_hat = 71.6499, Error = 7.3110
# Iteración 251: R_hat = 71.6562, Error = 7.3070
# Iteración 252: R_hat = 71.6625, Error = 7.3031
# Iteración 253: R_hat = 71.6688, Error = 7.2991
# Iteración 254: R_hat = 71.6751, Error = 7.2951
# Iteración 255: R_hat = 71.6814, Error = 7.2912
# Iteración 256: R_hat = 71.6876, Error = 7.2872
# Iteración 257: R_hat = 71.6939, Error = 7.2833
# Iteración 258: R_hat = 71.7002, Error = 7.2793
# Iteración 259: R_hat = 71.7065, Error = 7.2754
# Iteración 260: R_hat = 71.7128, Error = 7.2714
# Iteración 261: R_hat = 71.7190, Error = 7.2675
# Iteración 262: R_hat = 71.7253, Error = 7.2635
# Iteración 263: R_hat = 71.7316, Error = 7.2596
# Iteración 264: R_hat = 71.7379, Error = 7.2557
# Iteración 265: R_hat = 71.7441, Error = 7.2517
# Iteración 266: R_hat = 71.7504, Error = 7.2478
# Iteración 267: R_hat = 71.7567, Error = 7.2439
# Iteración 268: R_hat = 71.7629, Error = 7.2400
# Iteración 269: R_hat = 71.7692, Error = 7.2361
# Iteración 270: R_hat = 71.7754, Error = 7.2321
# Iteración 271: R_hat = 71.7817, Error = 7.2282
# Iteración 272: R_hat = 71.7879, Error = 7.2243
# Iteración 273: R_hat = 71.7942, Error = 7.2204
# Iteración 274: R_hat = 71.8004, Error = 7.2165
# Iteración 275: R_hat = 71.8067, Error = 7.2126
# Iteración 276: R_hat = 71.8129, Error = 7.2087
# Iteración 277: R_hat = 71.8192, Error = 7.2048
# Iteración 278: R_hat = 71.8254, Error = 7.2009
# Iteración 279: R_hat = 71.8316, Error = 7.1970
# Iteración 280: R_hat = 71.8379, Error = 7.1931
# Iteración 281: R_hat = 71.8441, Error = 7.1893
# Iteración 282: R_hat = 71.8503, Error = 7.1854
# Iteración 283: R_hat = 71.8566, Error = 7.1815
# Iteración 284: R_hat = 71.8628, Error = 7.1776
# Iteración 285: R_hat = 71.8690, Error = 7.1737
# Iteración 286: R_hat = 71.8752, Error = 7.1699
# Iteración 287: R_hat = 71.8814, Error = 7.1660
# Iteración 288: R_hat = 71.8876, Error = 7.1621
# Iteración 289: R_hat = 71.8939, Error = 7.1583
# Iteración 290: R_hat = 71.9001, Error = 7.1544
# Iteración 291: R_hat = 71.9063, Error = 7.1506
# Iteración 292: R_hat = 71.9125, Error = 7.1467
# Iteración 293: R_hat = 71.9187, Error = 7.1429
# Iteración 294: R_hat = 71.9249, Error = 7.1390
# Iteración 295: R_hat = 71.9311, Error = 7.1352
# Iteración 296: R_hat = 71.9373, Error = 7.1313
# Iteración 297: R_hat = 71.9435, Error = 7.1275
# Iteración 298: R_hat = 71.9497, Error = 7.1236
# Iteración 299: R_hat = 71.9559, Error = 7.1198
# Iteración 300: R_hat = 71.9621, Error = 7.1160
# Iteración 301: R_hat = 71.9682, Error = 7.1121
# Iteración 302: R_hat = 71.9744, Error = 7.1083
# Iteración 303: R_hat = 71.9806, Error = 7.1045
# Iteración 304: R_hat = 71.9868, Error = 7.1007
# Iteración 305: R_hat = 71.9930, Error = 7.0969
# Iteración 306: R_hat = 71.9991, Error = 7.0930
# Iteración 307: R_hat = 72.0053, Error = 7.0892
# Iteración 308: R_hat = 72.0115, Error = 7.0854
# Iteración 309: R_hat = 72.0177, Error = 7.0816
# Iteración 310: R_hat = 72.0238, Error = 7.0778
# Iteración 311: R_hat = 72.0300, Error = 7.0740
# Iteración 312: R_hat = 72.0361, Error = 7.0702
# Iteración 313: R_hat = 72.0423, Error = 7.0664
# Iteración 314: R_hat = 72.0485, Error = 7.0626
# Iteración 315: R_hat = 72.0546, Error = 7.0588
# Iteración 316: R_hat = 72.0608, Error = 7.0550
# Iteración 317: R_hat = 72.0669, Error = 7.0513
# Iteración 318: R_hat = 72.0731, Error = 7.0475
# Iteración 319: R_hat = 72.0792, Error = 7.0437
# Iteración 320: R_hat = 72.0854, Error = 7.0399
# Iteración 321: R_hat = 72.0915, Error = 7.0361
# Iteración 322: R_hat = 72.0976, Error = 7.0324
# Iteración 323: R_hat = 72.1038, Error = 7.0286
# Iteración 324: R_hat = 72.1099, Error = 7.0248
# Iteración 325: R_hat = 72.1161, Error = 7.0211
# Iteración 326: R_hat = 72.1222, Error = 7.0173
# Iteración 327: R_hat = 72.1283, Error = 7.0135
# Iteración 328: R_hat = 72.1344, Error = 7.0098
# Iteración 329: R_hat = 72.1406, Error = 7.0060
# Iteración 330: R_hat = 72.1467, Error = 7.0023
# Iteración 331: R_hat = 72.1528, Error = 6.9985
# Iteración 332: R_hat = 72.1589, Error = 6.9948
# Iteración 333: R_hat = 72.1650, Error = 6.9911
# Iteración 334: R_hat = 72.1712, Error = 6.9873
# Iteración 335: R_hat = 72.1773, Error = 6.9836
# Iteración 336: R_hat = 72.1834, Error = 6.9798
# Iteración 337: R_hat = 72.1895, Error = 6.9761
# Iteración 338: R_hat = 72.1956, Error = 6.9724
# Iteración 339: R_hat = 72.2017, Error = 6.9687
# Iteración 340: R_hat = 72.2078, Error = 6.9649
# Iteración 341: R_hat = 72.2139, Error = 6.9612
# Iteración 342: R_hat = 72.2200, Error = 6.9575
# Iteración 343: R_hat = 72.2261, Error = 6.9538
# Iteración 344: R_hat = 72.2322, Error = 6.9501
# Iteración 345: R_hat = 72.2383, Error = 6.9463
# Iteración 346: R_hat = 72.2444, Error = 6.9426
# Iteración 347: R_hat = 72.2504, Error = 6.9389
# Iteración 348: R_hat = 72.2565, Error = 6.9352
# Iteración 349: R_hat = 72.2626, Error = 6.9315
# Iteración 350: R_hat = 72.2687, Error = 6.9278
# Iteración 351: R_hat = 72.2748, Error = 6.9241
# Iteración 352: R_hat = 72.2808, Error = 6.9204
# Iteración 353: R_hat = 72.2869, Error = 6.9168
# Iteración 354: R_hat = 72.2930, Error = 6.9131
# Iteración 355: R_hat = 72.2991, Error = 6.9094
# Iteración 356: R_hat = 72.3051, Error = 6.9057
# Iteración 357: R_hat = 72.3112, Error = 6.9020
# Iteración 358: R_hat = 72.3172, Error = 6.8983
# Iteración 359: R_hat = 72.3233, Error = 6.8947
# Iteración 360: R_hat = 72.3294, Error = 6.8910
# Iteración 361: R_hat = 72.3354, Error = 6.8873
# Iteración 362: R_hat = 72.3415, Error = 6.8837
# Iteración 363: R_hat = 72.3475, Error = 6.8800
# Iteración 364: R_hat = 72.3536, Error = 6.8763
# Iteración 365: R_hat = 72.3596, Error = 6.8727
# Iteración 366: R_hat = 72.3657, Error = 6.8690
# Iteración 367: R_hat = 72.3717, Error = 6.8654
# Iteración 368: R_hat = 72.3777, Error = 6.8617
# Iteración 369: R_hat = 72.3838, Error = 6.8581
# Iteración 370: R_hat = 72.3898, Error = 6.8544
# Iteración 371: R_hat = 72.3959, Error = 6.8508
# Iteración 372: R_hat = 72.4019, Error = 6.8471
# Iteración 373: R_hat = 72.4079, Error = 6.8435
# Iteración 374: R_hat = 72.4139, Error = 6.8399
# Iteración 375: R_hat = 72.4200, Error = 6.8362
# Iteración 376: R_hat = 72.4260, Error = 6.8326
# Iteración 377: R_hat = 72.4320, Error = 6.8290
# Iteración 378: R_hat = 72.4380, Error = 6.8253
# Iteración 379: R_hat = 72.4441, Error = 6.8217
# Iteración 380: R_hat = 72.4501, Error = 6.8181
# Iteración 381: R_hat = 72.4561, Error = 6.8145
# Iteración 382: R_hat = 72.4621, Error = 6.8109
# Iteración 383: R_hat = 72.4681, Error = 6.8073
# Iteración 384: R_hat = 72.4741, Error = 6.8037
# Iteración 385: R_hat = 72.4801, Error = 6.8000
# Iteración 386: R_hat = 72.4861, Error = 6.7964
# Iteración 387: R_hat = 72.4921, Error = 6.7928
# Iteración 388: R_hat = 72.4981, Error = 6.7892
# Iteración 389: R_hat = 72.5041, Error = 6.7856
# Iteración 390: R_hat = 72.5101, Error = 6.7820
# Iteración 391: R_hat = 72.5161, Error = 6.7785
# Iteración 392: R_hat = 72.5221, Error = 6.7749
# Iteración 393: R_hat = 72.5281, Error = 6.7713
# Iteración 394: R_hat = 72.5341, Error = 6.7677
# Iteración 395: R_hat = 72.5400, Error = 6.7641
# Iteración 396: R_hat = 72.5460, Error = 6.7605
# Iteración 397: R_hat = 72.5520, Error = 6.7570
# Iteración 398: R_hat = 72.5580, Error = 6.7534
# Iteración 399: R_hat = 72.5640, Error = 6.7498
# Iteración 400: R_hat = 72.5699, Error = 6.7462
# Iteración 401: R_hat = 72.5759, Error = 6.7427
# Iteración 402: R_hat = 72.5819, Error = 6.7391
# Iteración 403: R_hat = 72.5878, Error = 6.7355
# Iteración 404: R_hat = 72.5938, Error = 6.7320
# Iteración 405: R_hat = 72.5998, Error = 6.7284
# Iteración 406: R_hat = 72.6057, Error = 6.7249
# Iteración 407: R_hat = 72.6117, Error = 6.7213
# Iteración 408: R_hat = 72.6176, Error = 6.7178
# Iteración 409: R_hat = 72.6236, Error = 6.7142
# Iteración 410: R_hat = 72.6295, Error = 6.7107
# Iteración 411: R_hat = 72.6355, Error = 6.7071
# Iteración 412: R_hat = 72.6414, Error = 6.7036
# Iteración 413: R_hat = 72.6474, Error = 6.7001
# Iteración 414: R_hat = 72.6533, Error = 6.6965
# Iteración 415: R_hat = 72.6593, Error = 6.6930
# Iteración 416: R_hat = 72.6652, Error = 6.6895
# Iteración 417: R_hat = 72.6712, Error = 6.6859
# Iteración 418: R_hat = 72.6771, Error = 6.6824
# Iteración 419: R_hat = 72.6830, Error = 6.6789
# Iteración 420: R_hat = 72.6890, Error = 6.6754
# Iteración 421: R_hat = 72.6949, Error = 6.6718
# Iteración 422: R_hat = 72.7008, Error = 6.6683
# Iteración 423: R_hat = 72.7067, Error = 6.6648
# Iteración 424: R_hat = 72.7127, Error = 6.6613
# Iteración 425: R_hat = 72.7186, Error = 6.6578
# Iteración 426: R_hat = 72.7245, Error = 6.6543
# Iteración 427: R_hat = 72.7304, Error = 6.6508
# Iteración 428: R_hat = 72.7363, Error = 6.6473
# Iteración 429: R_hat = 72.7422, Error = 6.6438
# Iteración 430: R_hat = 72.7482, Error = 6.6403
# Iteración 431: R_hat = 72.7541, Error = 6.6368
# Iteración 432: R_hat = 72.7600, Error = 6.6333
# Iteración 433: R_hat = 72.7659, Error = 6.6298
# Iteración 434: R_hat = 72.7718, Error = 6.6263
# Iteración 435: R_hat = 72.7777, Error = 6.6229
# Iteración 436: R_hat = 72.7836, Error = 6.6194
# Iteración 437: R_hat = 72.7895, Error = 6.6159
# Iteración 438: R_hat = 72.7954, Error = 6.6124
# Iteración 439: R_hat = 72.8013, Error = 6.6089
# Iteración 440: R_hat = 72.8071, Error = 6.6055
# Iteración 441: R_hat = 72.8130, Error = 6.6020
# Iteración 442: R_hat = 72.8189, Error = 6.5985
# Iteración 443: R_hat = 72.8248, Error = 6.5951
# Iteración 444: R_hat = 72.8307, Error = 6.5916
# Iteración 445: R_hat = 72.8366, Error = 6.5882
# Iteración 446: R_hat = 72.8424, Error = 6.5847
# Iteración 447: R_hat = 72.8483, Error = 6.5812
# Iteración 448: R_hat = 72.8542, Error = 6.5778
# Iteración 449: R_hat = 72.8601, Error = 6.5743
# Iteración 450: R_hat = 72.8659, Error = 6.5709
# Iteración 451: R_hat = 72.8718, Error = 6.5675
# Iteración 452: R_hat = 72.8777, Error = 6.5640
# Iteración 453: R_hat = 72.8835, Error = 6.5606
# Iteración 454: R_hat = 72.8894, Error = 6.5571
# Iteración 455: R_hat = 72.8953, Error = 6.5537
# Iteración 456: R_hat = 72.9011, Error = 6.5503
# Iteración 457: R_hat = 72.9070, Error = 6.5468
# Iteración 458: R_hat = 72.9128, Error = 6.5434
# Iteración 459: R_hat = 72.9187, Error = 6.5400
# Iteración 460: R_hat = 72.9245, Error = 6.5366
# Iteración 461: R_hat = 72.9304, Error = 6.5331
# Iteración 462: R_hat = 72.9362, Error = 6.5297
# Iteración 463: R_hat = 72.9421, Error = 6.5263
# Iteración 464: R_hat = 72.9479, Error = 6.5229
# Iteración 465: R_hat = 72.9537, Error = 6.5195
# Iteración 466: R_hat = 72.9596, Error = 6.5161
# Iteración 467: R_hat = 72.9654, Error = 6.5127
# Iteración 468: R_hat = 72.9712, Error = 6.5093
# Iteración 469: R_hat = 72.9771, Error = 6.5058
# Iteración 470: R_hat = 72.9829, Error = 6.5024
# Iteración 471: R_hat = 72.9887, Error = 6.4991
# Iteración 472: R_hat = 72.9946, Error = 6.4957
# Iteración 473: R_hat = 73.0004, Error = 6.4923
# Iteración 474: R_hat = 73.0062, Error = 6.4889
# Iteración 475: R_hat = 73.0120, Error = 6.4855
# Iteración 476: R_hat = 73.0178, Error = 6.4821
# Iteración 477: R_hat = 73.0237, Error = 6.4787
# Iteración 478: R_hat = 73.0295, Error = 6.4753
# Iteración 479: R_hat = 73.0353, Error = 6.4720
# Iteración 480: R_hat = 73.0411, Error = 6.4686
# Iteración 481: R_hat = 73.0469, Error = 6.4652
# Iteración 482: R_hat = 73.0527, Error = 6.4618
# Iteración 483: R_hat = 73.0585, Error = 6.4585
# Iteración 484: R_hat = 73.0643, Error = 6.4551
# Iteración 485: R_hat = 73.0701, Error = 6.4517
# Iteración 486: R_hat = 73.0759, Error = 6.4484
# Iteración 487: R_hat = 73.0817, Error = 6.4450
# Iteración 488: R_hat = 73.0875, Error = 6.4417
# Iteración 489: R_hat = 73.0933, Error = 6.4383
# Iteración 490: R_hat = 73.0991, Error = 6.4349
# Iteración 491: R_hat = 73.1049, Error = 6.4316
# Iteración 492: R_hat = 73.1106, Error = 6.4282
# Iteración 493: R_hat = 73.1164, Error = 6.4249
# Iteración 494: R_hat = 73.1222, Error = 6.4216
# Iteración 495: R_hat = 73.1280, Error = 6.4182
# Iteración 496: R_hat = 73.1338, Error = 6.4149
# Iteración 497: R_hat = 73.1395, Error = 6.4115
# Iteración 498: R_hat = 73.1453, Error = 6.4082
# Iteración 499: R_hat = 73.1511, Error = 6.4049
# Iteración 500: R_hat = 73.1569, Error = 6.4015
# Iteración 501: R_hat = 73.1626, Error = 6.3982
# Iteración 502: R_hat = 73.1684, Error = 6.3949
# Iteración 503: R_hat = 73.1742, Error = 6.3916
# Iteración 504: R_hat = 73.1799, Error = 6.3882
# Iteración 505: R_hat = 73.1857, Error = 6.3849
# Iteración 506: R_hat = 73.1914, Error = 6.3816
# Iteración 507: R_hat = 73.1972, Error = 6.3783
# Iteración 508: R_hat = 73.2029, Error = 6.3750
# Iteración 509: R_hat = 73.2087, Error = 6.3717
# Iteración 510: R_hat = 73.2144, Error = 6.3684
# Iteración 511: R_hat = 73.2202, Error = 6.3651
# Iteración 512: R_hat = 73.2259, Error = 6.3618
# Iteración 513: R_hat = 73.2317, Error = 6.3585
# Iteración 514: R_hat = 73.2374, Error = 6.3552
# Iteración 515: R_hat = 73.2432, Error = 6.3519
# Iteración 516: R_hat = 73.2489, Error = 6.3486
# Iteración 517: R_hat = 73.2546, Error = 6.3453
# Iteración 518: R_hat = 73.2604, Error = 6.3420
# Iteración 519: R_hat = 73.2661, Error = 6.3387
# Iteración 520: R_hat = 73.2718, Error = 6.3354
# Iteración 521: R_hat = 73.2776, Error = 6.3321
# Iteración 522: R_hat = 73.2833, Error = 6.3288
# Iteración 523: R_hat = 73.2890, Error = 6.3256
# Iteración 524: R_hat = 73.2947, Error = 6.3223
# Iteración 525: R_hat = 73.3005, Error = 6.3190
# Iteración 526: R_hat = 73.3062, Error = 6.3157
# Iteración 527: R_hat = 73.3119, Error = 6.3125
# Iteración 528: R_hat = 73.3176, Error = 6.3092
# Iteración 529: R_hat = 73.3233, Error = 6.3059
# Iteración 530: R_hat = 73.3290, Error = 6.3027
# Iteración 531: R_hat = 73.3347, Error = 6.2994
# Iteración 532: R_hat = 73.3404, Error = 6.2962
# Iteración 533: R_hat = 73.3461, Error = 6.2929
# Iteración 534: R_hat = 73.3518, Error = 6.2897
# Iteración 535: R_hat = 73.3575, Error = 6.2864
# Iteración 536: R_hat = 73.3632, Error = 6.2832
# Iteración 537: R_hat = 73.3689, Error = 6.2799
# Iteración 538: R_hat = 73.3746, Error = 6.2767
# Iteración 539: R_hat = 73.3803, Error = 6.2734
# Iteración 540: R_hat = 73.3860, Error = 6.2702
# Iteración 541: R_hat = 73.3917, Error = 6.2669
# Iteración 542: R_hat = 73.3974, Error = 6.2637
# Iteración 543: R_hat = 73.4031, Error = 6.2605
# Iteración 544: R_hat = 73.4088, Error = 6.2572
# Iteración 545: R_hat = 73.4144, Error = 6.2540
# Iteración 546: R_hat = 73.4201, Error = 6.2508
# Iteración 547: R_hat = 73.4258, Error = 6.2476
# Iteración 548: R_hat = 73.4315, Error = 6.2443
# Iteración 549: R_hat = 73.4372, Error = 6.2411
# Iteración 550: R_hat = 73.4428, Error = 6.2379
# Iteración 551: R_hat = 73.4485, Error = 6.2347
# Iteración 552: R_hat = 73.4542, Error = 6.2315
# Iteración 553: R_hat = 73.4598, Error = 6.2283
# Iteración 554: R_hat = 73.4655, Error = 6.2250
# Iteración 555: R_hat = 73.4712, Error = 6.2218
# Iteración 556: R_hat = 73.4768, Error = 6.2186
# Iteración 557: R_hat = 73.4825, Error = 6.2154
# Iteración 558: R_hat = 73.4881, Error = 6.2122
# Iteración 559: R_hat = 73.4938, Error = 6.2090
# Iteración 560: R_hat = 73.4994, Error = 6.2058
# Iteración 561: R_hat = 73.5051, Error = 6.2026
# Iteración 562: R_hat = 73.5107, Error = 6.1994
# Iteración 563: R_hat = 73.5164, Error = 6.1963
# Iteración 564: R_hat = 73.5220, Error = 6.1931
# Iteración 565: R_hat = 73.5277, Error = 6.1899
# Iteración 566: R_hat = 73.5333, Error = 6.1867
# Iteración 567: R_hat = 73.5389, Error = 6.1835
# Iteración 568: R_hat = 73.5446, Error = 6.1803
# Iteración 569: R_hat = 73.5502, Error = 6.1772
# Iteración 570: R_hat = 73.5559, Error = 6.1740
# Iteración 571: R_hat = 73.5615, Error = 6.1708
# Iteración 572: R_hat = 73.5671, Error = 6.1676
# Iteración 573: R_hat = 73.5727, Error = 6.1645
# Iteración 574: R_hat = 73.5784, Error = 6.1613
# Iteración 575: R_hat = 73.5840, Error = 6.1581
# Iteración 576: R_hat = 73.5896, Error = 6.1550
# Iteración 577: R_hat = 73.5952, Error = 6.1518
# Iteración 578: R_hat = 73.6008, Error = 6.1487
# Iteración 579: R_hat = 73.6065, Error = 6.1455
# Iteración 580: R_hat = 73.6121, Error = 6.1424
# Iteración 581: R_hat = 73.6177, Error = 6.1392
# Iteración 582: R_hat = 73.6233, Error = 6.1361
# Iteración 583: R_hat = 73.6289, Error = 6.1329
# Iteración 584: R_hat = 73.6345, Error = 6.1298
# Iteración 585: R_hat = 73.6401, Error = 6.1266
# Iteración 586: R_hat = 73.6457, Error = 6.1235
# Iteración 587: R_hat = 73.6513, Error = 6.1203
# Iteración 588: R_hat = 73.6569, Error = 6.1172
# Iteración 589: R_hat = 73.6625, Error = 6.1141
# Iteración 590: R_hat = 73.6681, Error = 6.1109
# Iteración 591: R_hat = 73.6737, Error = 6.1078
# Iteración 592: R_hat = 73.6793, Error = 6.1047
# Iteración 593: R_hat = 73.6849, Error = 6.1016
# Iteración 594: R_hat = 73.6905, Error = 6.0984
# Iteración 595: R_hat = 73.6961, Error = 6.0953
# Iteración 596: R_hat = 73.7016, Error = 6.0922
# Iteración 597: R_hat = 73.7072, Error = 6.0891
# Iteración 598: R_hat = 73.7128, Error = 6.0860
# Iteración 599: R_hat = 73.7184, Error = 6.0828
# Iteración 600: R_hat = 73.7240, Error = 6.0797
# Iteración 601: R_hat = 73.7295, Error = 6.0766
# Iteración 602: R_hat = 73.7351, Error = 6.0735
# Iteración 603: R_hat = 73.7407, Error = 6.0704
# Iteración 604: R_hat = 73.7463, Error = 6.0673
# Iteración 605: R_hat = 73.7518, Error = 6.0642
# Iteración 606: R_hat = 73.7574, Error = 6.0611
# Iteración 607: R_hat = 73.7629, Error = 6.0580
# Iteración 608: R_hat = 73.7685, Error = 6.0549
# Iteración 609: R_hat = 73.7741, Error = 6.0518
# Iteración 610: R_hat = 73.7796, Error = 6.0487
# Iteración 611: R_hat = 73.7852, Error = 6.0456
# Iteración 612: R_hat = 73.7907, Error = 6.0426
# Iteración 613: R_hat = 73.7963, Error = 6.0395
# Iteración 614: R_hat = 73.8018, Error = 6.0364
# Iteración 615: R_hat = 73.8074, Error = 6.0333
# Iteración 616: R_hat = 73.8129, Error = 6.0302
# Iteración 617: R_hat = 73.8185, Error = 6.0272
# Iteración 618: R_hat = 73.8240, Error = 6.0241
# Iteración 619: R_hat = 73.8296, Error = 6.0210
# Iteración 620: R_hat = 73.8351, Error = 6.0179
# Iteración 621: R_hat = 73.8406, Error = 6.0149
# Iteración 622: R_hat = 73.8462, Error = 6.0118
# Iteración 623: R_hat = 73.8517, Error = 6.0087
# Iteración 624: R_hat = 73.8572, Error = 6.0057
# Iteración 625: R_hat = 73.8628, Error = 6.0026
# Iteración 626: R_hat = 73.8683, Error = 5.9996
# Iteración 627: R_hat = 73.8738, Error = 5.9965
# Iteración 628: R_hat = 73.8794, Error = 5.9935
# Iteración 629: R_hat = 73.8849, Error = 5.9904
# Iteración 630: R_hat = 73.8904, Error = 5.9874
# Iteración 631: R_hat = 73.8959, Error = 5.9843
# Iteración 632: R_hat = 73.9014, Error = 5.9813
# Iteración 633: R_hat = 73.9069, Error = 5.9782
# Iteración 634: R_hat = 73.9125, Error = 5.9752
# Iteración 635: R_hat = 73.9180, Error = 5.9721
# Iteración 636: R_hat = 73.9235, Error = 5.9691
# Iteración 637: R_hat = 73.9290, Error = 5.9661
# Iteración 638: R_hat = 73.9345, Error = 5.9630
# Iteración 639: R_hat = 73.9400, Error = 5.9600
# Iteración 640: R_hat = 73.9455, Error = 5.9570
# Iteración 641: R_hat = 73.9510, Error = 5.9539
# Iteración 642: R_hat = 73.9565, Error = 5.9509
# Iteración 643: R_hat = 73.9620, Error = 5.9479
# Iteración 644: R_hat = 73.9675, Error = 5.9449
# Iteración 645: R_hat = 73.9730, Error = 5.9419
# Iteración 646: R_hat = 73.9785, Error = 5.9388
# Iteración 647: R_hat = 73.9840, Error = 5.9358
# Iteración 648: R_hat = 73.9895, Error = 5.9328
# Iteración 649: R_hat = 73.9949, Error = 5.9298
# Iteración 650: R_hat = 74.0004, Error = 5.9268
# Iteración 651: R_hat = 74.0059, Error = 5.9238
# Iteración 652: R_hat = 74.0114, Error = 5.9208
# Iteración 653: R_hat = 74.0169, Error = 5.9178
# Iteración 654: R_hat = 74.0223, Error = 5.9148
# Iteración 655: R_hat = 74.0278, Error = 5.9118
# Iteración 656: R_hat = 74.0333, Error = 5.9088
# Iteración 657: R_hat = 74.0388, Error = 5.9058
# Iteración 658: R_hat = 74.0442, Error = 5.9028
# Iteración 659: R_hat = 74.0497, Error = 5.8998
# Iteración 660: R_hat = 74.0552, Error = 5.8968
# Iteración 661: R_hat = 74.0606, Error = 5.8938
# Iteración 662: R_hat = 74.0661, Error = 5.8908
# Iteración 663: R_hat = 74.0715, Error = 5.8879
# Iteración 664: R_hat = 74.0770, Error = 5.8849
# Iteración 665: R_hat = 74.0825, Error = 5.8819
# Iteración 666: R_hat = 74.0879, Error = 5.8789
# Iteración 667: R_hat = 74.0934, Error = 5.8760
# Iteración 668: R_hat = 74.0988, Error = 5.8730
# Iteración 669: R_hat = 74.1043, Error = 5.8700
# Iteración 670: R_hat = 74.1097, Error = 5.8670
# Iteración 671: R_hat = 74.1152, Error = 5.8641
# Iteración 672: R_hat = 74.1206, Error = 5.8611
# Iteración 673: R_hat = 74.1260, Error = 5.8581
# Iteración 674: R_hat = 74.1315, Error = 5.8552
# Iteración 675: R_hat = 74.1369, Error = 5.8522
# Iteración 676: R_hat = 74.1424, Error = 5.8493
# Iteración 677: R_hat = 74.1478, Error = 5.8463
# Iteración 678: R_hat = 74.1532, Error = 5.8434
# Iteración 679: R_hat = 74.1587, Error = 5.8404
# Iteración 680: R_hat = 74.1641, Error = 5.8375
# Iteración 681: R_hat = 74.1695, Error = 5.8345
# Iteración 682: R_hat = 74.1749, Error = 5.8316
# Iteración 683: R_hat = 74.1804, Error = 5.8286
# Iteración 684: R_hat = 74.1858, Error = 5.8257
# Iteración 685: R_hat = 74.1912, Error = 5.8227
# Iteración 686: R_hat = 74.1966, Error = 5.8198
# Iteración 687: R_hat = 74.2020, Error = 5.8169
# Iteración 688: R_hat = 74.2075, Error = 5.8139
# Iteración 689: R_hat = 74.2129, Error = 5.8110
# Iteración 690: R_hat = 74.2183, Error = 5.8081
# Iteración 691: R_hat = 74.2237, Error = 5.8051
# Iteración 692: R_hat = 74.2291, Error = 5.8022
# Iteración 693: R_hat = 74.2345, Error = 5.7993
# Iteración 694: R_hat = 74.2399, Error = 5.7964
# Iteración 695: R_hat = 74.2453, Error = 5.7934
# Iteración 696: R_hat = 74.2507, Error = 5.7905
# Iteración 697: R_hat = 74.2561, Error = 5.7876
# Iteración 698: R_hat = 74.2615, Error = 5.7847
# Iteración 699: R_hat = 74.2669, Error = 5.7818
# Iteración 700: R_hat = 74.2723, Error = 5.7789
# Iteración 701: R_hat = 74.2777, Error = 5.7760
# Iteración 702: R_hat = 74.2831, Error = 5.7731
# Iteración 703: R_hat = 74.2885, Error = 5.7702
# Iteración 704: R_hat = 74.2939, Error = 5.7673
# Iteración 705: R_hat = 74.2992, Error = 5.7644
# Iteración 706: R_hat = 74.3046, Error = 5.7615
# Iteración 707: R_hat = 74.3100, Error = 5.7586
# Iteración 708: R_hat = 74.3154, Error = 5.7557
# Iteración 709: R_hat = 74.3208, Error = 5.7528
# Iteración 710: R_hat = 74.3261, Error = 5.7499
# Iteración 711: R_hat = 74.3315, Error = 5.7470
# Iteración 712: R_hat = 74.3369, Error = 5.7441
# Iteración 713: R_hat = 74.3423, Error = 5.7412
# Iteración 714: R_hat = 74.3476, Error = 5.7383
# Iteración 715: R_hat = 74.3530, Error = 5.7354
# Iteración 716: R_hat = 74.3584, Error = 5.7326
# Iteración 717: R_hat = 74.3637, Error = 5.7297
# Iteración 718: R_hat = 74.3691, Error = 5.7268
# Iteración 719: R_hat = 74.3744, Error = 5.7239
# Iteración 720: R_hat = 74.3798, Error = 5.7211
# Iteración 721: R_hat = 74.3852, Error = 5.7182
# Iteración 722: R_hat = 74.3905, Error = 5.7153
# Iteración 723: R_hat = 74.3959, Error = 5.7125
# Iteración 724: R_hat = 74.4012, Error = 5.7096
# Iteración 725: R_hat = 74.4066, Error = 5.7067
# Iteración 726: R_hat = 74.4119, Error = 5.7039
# Iteración 727: R_hat = 74.4173, Error = 5.7010
# Iteración 728: R_hat = 74.4226, Error = 5.6982
# Iteración 729: R_hat = 74.4280, Error = 5.6953
# Iteración 730: R_hat = 74.4333, Error = 5.6924
# Iteración 731: R_hat = 74.4386, Error = 5.6896
# Iteración 732: R_hat = 74.4440, Error = 5.6867
# Iteración 733: R_hat = 74.4493, Error = 5.6839
# Iteración 734: R_hat = 74.4546, Error = 5.6810
# Iteración 735: R_hat = 74.4600, Error = 5.6782
# Iteración 736: R_hat = 74.4653, Error = 5.6754
# Iteración 737: R_hat = 74.4706, Error = 5.6725
# Iteración 738: R_hat = 74.4760, Error = 5.6697
# Iteración 739: R_hat = 74.4813, Error = 5.6668
# Iteración 740: R_hat = 74.4866, Error = 5.6640
# Iteración 741: R_hat = 74.4919, Error = 5.6612
# Iteración 742: R_hat = 74.4972, Error = 5.6583
# Iteración 743: R_hat = 74.5026, Error = 5.6555
# Iteración 744: R_hat = 74.5079, Error = 5.6527
# Iteración 745: R_hat = 74.5132, Error = 5.6499
# Iteración 746: R_hat = 74.5185, Error = 5.6470
# Iteración 747: R_hat = 74.5238, Error = 5.6442
# Iteración 748: R_hat = 74.5291, Error = 5.6414
# Iteración 749: R_hat = 74.5344, Error = 5.6386
# Iteración 750: R_hat = 74.5397, Error = 5.6358
# Iteración 751: R_hat = 74.5450, Error = 5.6329
# Iteración 752: R_hat = 74.5503, Error = 5.6301
# Iteración 753: R_hat = 74.5556, Error = 5.6273
# Iteración 754: R_hat = 74.5609, Error = 5.6245
# Iteración 755: R_hat = 74.5662, Error = 5.6217
# Iteración 756: R_hat = 74.5715, Error = 5.6189
# Iteración 757: R_hat = 74.5768, Error = 5.6161
# Iteración 758: R_hat = 74.5821, Error = 5.6133
# Iteración 759: R_hat = 74.5874, Error = 5.6105
# Iteración 760: R_hat = 74.5927, Error = 5.6077
# Iteración 761: R_hat = 74.5980, Error = 5.6049
# Iteración 762: R_hat = 74.6033, Error = 5.6021
# Iteración 763: R_hat = 74.6086, Error = 5.5993
# Iteración 764: R_hat = 74.6138, Error = 5.5965
# Iteración 765: R_hat = 74.6191, Error = 5.5937
# Iteración 766: R_hat = 74.6244, Error = 5.5909
# Iteración 767: R_hat = 74.6297, Error = 5.5882
# Iteración 768: R_hat = 74.6349, Error = 5.5854
# Iteración 769: R_hat = 74.6402, Error = 5.5826
# Iteración 770: R_hat = 74.6455, Error = 5.5798
# Iteración 771: R_hat = 74.6508, Error = 5.5770
# Iteración 772: R_hat = 74.6560, Error = 5.5743
# Iteración 773: R_hat = 74.6613, Error = 5.5715
# Iteración 774: R_hat = 74.6666, Error = 5.5687
# Iteración 775: R_hat = 74.6718, Error = 5.5659
# Iteración 776: R_hat = 74.6771, Error = 5.5632
# Iteración 777: R_hat = 74.6823, Error = 5.5604
# Iteración 778: R_hat = 74.6876, Error = 5.5576
# Iteración 779: R_hat = 74.6929, Error = 5.5549
# Iteración 780: R_hat = 74.6981, Error = 5.5521
# Iteración 781: R_hat = 74.7034, Error = 5.5494
# Iteración 782: R_hat = 74.7086, Error = 5.5466
# Iteración 783: R_hat = 74.7139, Error = 5.5438
# Iteración 784: R_hat = 74.7191, Error = 5.5411
# Iteración 785: R_hat = 74.7244, Error = 5.5383
# Iteración 786: R_hat = 74.7296, Error = 5.5356
# Iteración 787: R_hat = 74.7348, Error = 5.5328
# Iteración 788: R_hat = 74.7401, Error = 5.5301
# Iteración 789: R_hat = 74.7453, Error = 5.5273
# Iteración 790: R_hat = 74.7506, Error = 5.5246
# Iteración 791: R_hat = 74.7558, Error = 5.5218
# Iteración 792: R_hat = 74.7610, Error = 5.5191
# Iteración 793: R_hat = 74.7663, Error = 5.5164
# Iteración 794: R_hat = 74.7715, Error = 5.5136
# Iteración 795: R_hat = 74.7767, Error = 5.5109
# Iteración 796: R_hat = 74.7819, Error = 5.5082
# Iteración 797: R_hat = 74.7872, Error = 5.5054
# Iteración 798: R_hat = 74.7924, Error = 5.5027
# Iteración 799: R_hat = 74.7976, Error = 5.5000
# Iteración 800: R_hat = 74.8028, Error = 5.4972
# Iteración 801: R_hat = 74.8081, Error = 5.4945
# Iteración 802: R_hat = 74.8133, Error = 5.4918
# Iteración 803: R_hat = 74.8185, Error = 5.4891
# Iteración 804: R_hat = 74.8237, Error = 5.4864
# Iteración 805: R_hat = 74.8289, Error = 5.4836
# Iteración 806: R_hat = 74.8341, Error = 5.4809
# Iteración 807: R_hat = 74.8393, Error = 5.4782
# Iteración 808: R_hat = 74.8445, Error = 5.4755
# Iteración 809: R_hat = 74.8497, Error = 5.4728
# Iteración 810: R_hat = 74.8549, Error = 5.4701
# Iteración 811: R_hat = 74.8601, Error = 5.4674
# Iteración 812: R_hat = 74.8653, Error = 5.4647
# Iteración 813: R_hat = 74.8705, Error = 5.4620
# Iteración 814: R_hat = 74.8757, Error = 5.4593
# Iteración 815: R_hat = 74.8809, Error = 5.4566
# Iteración 816: R_hat = 74.8861, Error = 5.4539
# Iteración 817: R_hat = 74.8913, Error = 5.4512
# Iteración 818: R_hat = 74.8965, Error = 5.4485
# Iteración 819: R_hat = 74.9017, Error = 5.4458
# Iteración 820: R_hat = 74.9069, Error = 5.4431
# Iteración 821: R_hat = 74.9121, Error = 5.4404
# Iteración 822: R_hat = 74.9173, Error = 5.4377
# Iteración 823: R_hat = 74.9224, Error = 5.4350
# Iteración 824: R_hat = 74.9276, Error = 5.4323
# Iteración 825: R_hat = 74.9328, Error = 5.4297
# Iteración 826: R_hat = 74.9380, Error = 5.4270
# Iteración 827: R_hat = 74.9431, Error = 5.4243
# Iteración 828: R_hat = 74.9483, Error = 5.4216
# Iteración 829: R_hat = 74.9535, Error = 5.4189
# Iteración 830: R_hat = 74.9587, Error = 5.4163
# Iteración 831: R_hat = 74.9638, Error = 5.4136
# Iteración 832: R_hat = 74.9690, Error = 5.4109
# Iteración 833: R_hat = 74.9742, Error = 5.4083
# Iteración 834: R_hat = 74.9793, Error = 5.4056
# Iteración 835: R_hat = 74.9845, Error = 5.4029
# Iteración 836: R_hat = 74.9896, Error = 5.4003
# Iteración 837: R_hat = 74.9948, Error = 5.3976
# Iteración 838: R_hat = 75.0000, Error = 5.3949
# Iteración 839: R_hat = 75.0051, Error = 5.3923
# Iteración 840: R_hat = 75.0103, Error = 5.3896
# Iteración 841: R_hat = 75.0154, Error = 5.3870
# Iteración 842: R_hat = 75.0206, Error = 5.3843
# Iteración 843: R_hat = 75.0257, Error = 5.3817
# Iteración 844: R_hat = 75.0309, Error = 5.3790
# Iteración 845: R_hat = 75.0360, Error = 5.3764
# Iteración 846: R_hat = 75.0412, Error = 5.3737
# Iteración 847: R_hat = 75.0463, Error = 5.3711
# Iteración 848: R_hat = 75.0514, Error = 5.3684
# Iteración 849: R_hat = 75.0566, Error = 5.3658
# Iteración 850: R_hat = 75.0617, Error = 5.3631
# Iteración 851: R_hat = 75.0668, Error = 5.3605
# Iteración 852: R_hat = 75.0720, Error = 5.3579
# Iteración 853: R_hat = 75.0771, Error = 5.3552
# Iteración 854: R_hat = 75.0822, Error = 5.3526
# Iteración 855: R_hat = 75.0874, Error = 5.3500
# Iteración 856: R_hat = 75.0925, Error = 5.3473
# Iteración 857: R_hat = 75.0976, Error = 5.3447
# Iteración 858: R_hat = 75.1027, Error = 5.3421
# Iteración 859: R_hat = 75.1079, Error = 5.3395
# Iteración 860: R_hat = 75.1130, Error = 5.3368
# Iteración 861: R_hat = 75.1181, Error = 5.3342
# Iteración 862: R_hat = 75.1232, Error = 5.3316
# Iteración 863: R_hat = 75.1283, Error = 5.3290
# Iteración 864: R_hat = 75.1335, Error = 5.3264
# Iteración 865: R_hat = 75.1386, Error = 5.3238
# Iteración 866: R_hat = 75.1437, Error = 5.3211
# Iteración 867: R_hat = 75.1488, Error = 5.3185
# Iteración 868: R_hat = 75.1539, Error = 5.3159
# Iteración 869: R_hat = 75.1590, Error = 5.3133
# Iteración 870: R_hat = 75.1641, Error = 5.3107
# Iteración 871: R_hat = 75.1692, Error = 5.3081
# Iteración 872: R_hat = 75.1743, Error = 5.3055
# Iteración 873: R_hat = 75.1794, Error = 5.3029
# Iteración 874: R_hat = 75.1845, Error = 5.3003
# Iteración 875: R_hat = 75.1896, Error = 5.2977
# Iteración 876: R_hat = 75.1947, Error = 5.2951
# Iteración 877: R_hat = 75.1998, Error = 5.2925
# Iteración 878: R_hat = 75.2049, Error = 5.2899
# Iteración 879: R_hat = 75.2100, Error = 5.2873
# Iteración 880: R_hat = 75.2151, Error = 5.2847
# Iteración 881: R_hat = 75.2201, Error = 5.2821
# Iteración 882: R_hat = 75.2252, Error = 5.2796
# Iteración 883: R_hat = 75.2303, Error = 5.2770
# Iteración 884: R_hat = 75.2354, Error = 5.2744
# Iteración 885: R_hat = 75.2405, Error = 5.2718
# Iteración 886: R_hat = 75.2455, Error = 5.2692
# Iteración 887: R_hat = 75.2506, Error = 5.2667
# Iteración 888: R_hat = 75.2557, Error = 5.2641
# Iteración 889: R_hat = 75.2608, Error = 5.2615
# Iteración 890: R_hat = 75.2658, Error = 5.2589
# Iteración 891: R_hat = 75.2709, Error = 5.2564
# Iteración 892: R_hat = 75.2760, Error = 5.2538
# Iteración 893: R_hat = 75.2810, Error = 5.2512
# Iteración 894: R_hat = 75.2861, Error = 5.2487
# Iteración 895: R_hat = 75.2912, Error = 5.2461
# Iteración 896: R_hat = 75.2962, Error = 5.2435
# Iteración 897: R_hat = 75.3013, Error = 5.2410
# Iteración 898: R_hat = 75.3064, Error = 5.2384
# Iteración 899: R_hat = 75.3114, Error = 5.2358
# Iteración 900: R_hat = 75.3165, Error = 5.2333
# Iteración 901: R_hat = 75.3215, Error = 5.2307
# Iteración 902: R_hat = 75.3266, Error = 5.2282
# Iteración 903: R_hat = 75.3316, Error = 5.2256
# Iteración 904: R_hat = 75.3367, Error = 5.2231
# Iteración 905: R_hat = 75.3417, Error = 5.2205
# Iteración 906: R_hat = 75.3468, Error = 5.2180
# Iteración 907: R_hat = 75.3518, Error = 5.2154
# Iteración 908: R_hat = 75.3569, Error = 5.2129
# Iteración 909: R_hat = 75.3619, Error = 5.2103
# Iteración 910: R_hat = 75.3669, Error = 5.2078
# Iteración 911: R_hat = 75.3720, Error = 5.2053
# Iteración 912: R_hat = 75.3770, Error = 5.2027
# Iteración 913: R_hat = 75.3820, Error = 5.2002
# Iteración 914: R_hat = 75.3871, Error = 5.1977
# Iteración 915: R_hat = 75.3921, Error = 5.1951
# Iteración 916: R_hat = 75.3971, Error = 5.1926
# Iteración 917: R_hat = 75.4022, Error = 5.1901
# Iteración 918: R_hat = 75.4072, Error = 5.1875
# Iteración 919: R_hat = 75.4122, Error = 5.1850
# Iteración 920: R_hat = 75.4172, Error = 5.1825
# Iteración 921: R_hat = 75.4223, Error = 5.1800
# Iteración 922: R_hat = 75.4273, Error = 5.1774
# Iteración 923: R_hat = 75.4323, Error = 5.1749
# Iteración 924: R_hat = 75.4373, Error = 5.1724
# Iteración 925: R_hat = 75.4423, Error = 5.1699
# Iteración 926: R_hat = 75.4473, Error = 5.1674
# Iteración 927: R_hat = 75.4524, Error = 5.1649
# Iteración 928: R_hat = 75.4574, Error = 5.1623
# Iteración 929: R_hat = 75.4624, Error = 5.1598
# Iteración 930: R_hat = 75.4674, Error = 5.1573
# Iteración 931: R_hat = 75.4724, Error = 5.1548
# Iteración 932: R_hat = 75.4774, Error = 5.1523
# Iteración 933: R_hat = 75.4824, Error = 5.1498
# Iteración 934: R_hat = 75.4874, Error = 5.1473
# Iteración 935: R_hat = 75.4924, Error = 5.1448
# Iteración 936: R_hat = 75.4974, Error = 5.1423
# Iteración 937: R_hat = 75.5024, Error = 5.1398
# Iteración 938: R_hat = 75.5074, Error = 5.1373
# Iteración 939: R_hat = 75.5124, Error = 5.1348
# Iteración 940: R_hat = 75.5174, Error = 5.1323
# Iteración 941: R_hat = 75.5224, Error = 5.1298
# Iteración 942: R_hat = 75.5274, Error = 5.1273
# Iteración 943: R_hat = 75.5323, Error = 5.1249
# Iteración 944: R_hat = 75.5373, Error = 5.1224
# Iteración 945: R_hat = 75.5423, Error = 5.1199
# Iteración 946: R_hat = 75.5473, Error = 5.1174
# Iteración 947: R_hat = 75.5523, Error = 5.1149
# Iteración 948: R_hat = 75.5573, Error = 5.1124
# Iteración 949: R_hat = 75.5622, Error = 5.1100
# Iteración 950: R_hat = 75.5672, Error = 5.1075
# Iteración 951: R_hat = 75.5722, Error = 5.1050
# Iteración 952: R_hat = 75.5772, Error = 5.1025
# Iteración 953: R_hat = 75.5821, Error = 5.1001
# Iteración 954: R_hat = 75.5871, Error = 5.0976
# Iteración 955: R_hat = 75.5921, Error = 5.0951
# Iteración 956: R_hat = 75.5970, Error = 5.0927
# Iteración 957: R_hat = 75.6020, Error = 5.0902
# Iteración 958: R_hat = 75.6070, Error = 5.0877
# Iteración 959: R_hat = 75.6119, Error = 5.0853
# Iteración 960: R_hat = 75.6169, Error = 5.0828
# Iteración 961: R_hat = 75.6218, Error = 5.0803
# Iteración 962: R_hat = 75.6268, Error = 5.0779
# Iteración 963: R_hat = 75.6318, Error = 5.0754
# Iteración 964: R_hat = 75.6367, Error = 5.0730
# Iteración 965: R_hat = 75.6417, Error = 5.0705
# Iteración 966: R_hat = 75.6466, Error = 5.0681
# Iteración 967: R_hat = 75.6516, Error = 5.0656
# Iteración 968: R_hat = 75.6565, Error = 5.0632
# Iteración 969: R_hat = 75.6615, Error = 5.0607
# Iteración 970: R_hat = 75.6664, Error = 5.0583
# Iteración 971: R_hat = 75.6713, Error = 5.0558
# Iteración 972: R_hat = 75.6763, Error = 5.0534
# Iteración 973: R_hat = 75.6812, Error = 5.0509
# Iteración 974: R_hat = 75.6862, Error = 5.0485
# Iteración 975: R_hat = 75.6911, Error = 5.0461
# Iteración 976: R_hat = 75.6960, Error = 5.0436
# Iteración 977: R_hat = 75.7010, Error = 5.0412
# Iteración 978: R_hat = 75.7059, Error = 5.0387
# Iteración 979: R_hat = 75.7108, Error = 5.0363
# Iteración 980: R_hat = 75.7158, Error = 5.0339
# Iteración 981: R_hat = 75.7207, Error = 5.0315
# Iteración 982: R_hat = 75.7256, Error = 5.0290
# Iteración 983: R_hat = 75.7305, Error = 5.0266
# Iteración 984: R_hat = 75.7355, Error = 5.0242
# Iteración 985: R_hat = 75.7404, Error = 5.0218
# Iteración 986: R_hat = 75.7453, Error = 5.0193
# Iteración 987: R_hat = 75.7502, Error = 5.0169
# Iteración 988: R_hat = 75.7551, Error = 5.0145
# Iteración 989: R_hat = 75.7601, Error = 5.0121
# Iteración 990: R_hat = 75.7650, Error = 5.0097
# Iteración 991: R_hat = 75.7699, Error = 5.0072
# Iteración 992: R_hat = 75.7748, Error = 5.0048
# Iteración 993: R_hat = 75.7797, Error = 5.0024
# Iteración 994: R_hat = 75.7846, Error = 5.0000
# Iteración 995: R_hat = 75.7895, Error = 4.9976
# Iteración 996: R_hat = 75.7944, Error = 4.9952
# Iteración 997: R_hat = 75.7993, Error = 4.9928
# Iteración 998: R_hat = 75.8042, Error = 4.9904
# Iteración 999: R_hat = 75.8091, Error = 4.9880
# Iteración 1000: R_hat = 75.8140, Error = 4.9856
#
# R estimada = 75.8140 Ohms (R real = 100 Ohms)
